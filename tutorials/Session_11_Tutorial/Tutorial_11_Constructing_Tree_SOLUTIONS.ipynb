# %% [markdown]
# # Tutorial 11: Constructing the Tree — SOLUTIONS
#
# **FOR INSTRUCTOR USE ONLY**

# %%
library(Biostrings); library(msa); library(ape)

# %%
# SOLUTION: Step 2 - Align with ClustalW
alignment <- msa(seqs, method = "ClustalW")

# %%
# SOLUTION: Step 4 - Calculate distance (raw model)
dist_matrix <- dist.dna(dna_bin, model = "raw")

# %%
# SOLUTION: Step 5 - Build NJ tree
tree <- nj(dist_matrix)

# %% [markdown]
# ## Expected Interpretations
#
# 1. **Omicron cluster:** Patient_1_HK, Patient_2_HK, Patient_3_HK
#
# 2. **Delta cluster:** Patient_4_SZ, Patient_5_SZ
#
# 3. **Same outbreak?** No - HK patients have Omicron, SZ patients have Delta. These are separate introductions.
